# %%
import cv2
import numpy as np

# %%
img_rgb = cv2.imread('Test.jpg')
#plt.imshow(img_rgb)
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)

# %%
template = cv2.imread('template.jpg',0)
w, h = template.shape[::-1]
#print(template)

# %%
#1st template
res = cv2.matchTemplate(img_gray,template,cv2.TM_CCOEFF_NORMED)
threshold = 0.2262
loc = np.where( res >= threshold)
for pt in zip(*loc[::-1]):
    cv2.rectangle(img_rgb, pt, (pt[0] + w, pt[1] 
                                + h), (0,255,0), 4)

# %%
#2nd template
res1 = cv2.matchTemplate(img_gray,template,cv2.TM_CCOEFF_NORMED)
threshold = 0.2262
loc = np.where( res >= threshold)
for pt in zip(*loc[::-1]):
    cv2.rectangle(img_rgb, pt, (pt[0] + w, pt[1] 
                                + h), (0,255,0), 4)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2

# %%
#print(img_rgb)

# %%
plt.imshow(img_rgb)

# %%
plt.imshow(img_rgb)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2

img_rgb = cv2.imread('imgblank.jpg')
#plt.imshow(img_rgb)
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)
template = cv2.imread('template.jpg',0)
w, h = template.shape[::-1]
#print(template)
res = cv2.matchTemplate(img_gray,template,cv2.TM_CCOEFF_NORMED)
threshold = 0.8
#threshold = 0.2262
loc = np.where( res >= threshold)
for pt in zip(*loc[::-1]):
    cv2.rectangle(img_rgb, pt, (pt[0] + w, pt[1] + h), (0,255,0), 4)
plt.imshow(img_rgb)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
import time
start_time = time.time()
img_rgb = cv2.imread('Test.jpg')
#plt.imshow(img_rgb)
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)
template = cv2.imread('template.jpg',0)
w, h = template.shape[::-1]
#print(template)
res = cv2.matchTemplate(img_gray,template,cv2.TM_CCOEFF_NORMED)
threshold = 0.2262
loc = np.where( res >= threshold)
for pt in zip(*loc[::-1]):
    cv2.rectangle(img_rgb, pt, (pt[0] + w, pt[1] + h), (0,255,0), 4)
plt.imshow(img_rgb)
elapsed_time = time.time() - start_time

print(elapsed_time)
# Out:
# 0.07714986801147461
